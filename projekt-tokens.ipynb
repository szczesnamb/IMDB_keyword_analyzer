# %%
import nltk

# %%
from nltk.tokenize import word_tokenize

# %%
## TOKENIZATION ##

# Open file:
with open('fantasy0.txt', 'r') as file:
    for line in file:    
        # Split file into words: words
        tokens = word_tokenize(line)
        # Convert the tokens into lowercase: lower_tokens
        lower_tokens = [t.lower() for t in tokens]

# Print the unique tokens result
print(set(lower_tokens))
# Out:
# {'»', 'oath', 'alcove', 'finished', 'sewing', 'kings', 'manage', 'furtive', 'beacon', 'end', 'bag', 'pain', 'life', 'known', 'crosses', 'awake', 'suffering', 'tortures', 'precipice', 'dropping', 'begins', 'shuts', 'terror', 'exhaustion', 'opposes', 'recall', 'sarah', 'walks', 'remain', 'jumps', 'father', 'a', 'ungol', 'gondorian', 'nazgul', 'looting', 'outskirts', 'gladden', 'ordering', 'says', 'lest', 'food', 'viggo', 'continues', 'climbs', 'closer', 'towards', 'lightning', 'carry', 'bare', 'peace.sam', 'gollum', 'deep', 'bean', 'holds', 'barad-dă', 'she', 'victory', 'upper', '--', 'caves', 'makil', 'tyler', 'affection', 'heir', 'anduin', 'assuming', 'city', 'feet', 'before', 'break', 'miranda', "'s", 'fortify', 'leading', 'to', 'liv', 'long', 'thousand', 'walls', 'skirmish', 'lava', 'consumed', 'back', 'may', 'be', 'eating', 'stabs', 'lied', 'burning', 'slinking', 'spent', 'sight', 'saving', 'orthanc', 'treachery', 'uttermost', 'lights', 'enemy', 'hands', 'marshaled', 'straight', 'route', 'promise', 'unconscious', 'horse', 'way', 'north', 'boats', 'family', 'brief', 'submitted', 'crack', 'flame', 'amongst', 'stair', 'he', 'trying', 'ensues', 'ring', 'precious', 'gate', 'flashback', 'sends', 'recompense', 'quickly', 'encampment', 'smă©agol', 'days', 'once', 'lair', 'head-long', 'ian', 'cunning', 'believes', 'wounding', 'curse', 'passes', 'in', 'empathises', 'allegiance', 'sauron.meanwhile', 'thrown', 'amidst', 'galadriel', 'loyalty', 'mckellen', 'refuses', 'still', 'burns', 'decides', 'cirith', 'plan', 'inside', 'heads', 'shame', 'time', 'entranced', 'christopher', 'positions', 'awakes', 'wary', 'get', 'merry', 'over', 'first', 'dead', 'lower', 'peace', 'now', 'osgiliath', 'great', 'sean', 'briefly', 'saddles', 'passing', 'harad', 'turns', 'massacring', 'both', 'meet', 'is', 'cloak.the', 'refuge', 'again', 'biting', 'mortensen', 'sailing', 'horn', 'stop', 'set', 'fangorn', 'rejoices', 'hears', 'stirring', 'forsaken', 'record', 'together', 'path', 'urging', 'morannon', 'water', 'david', 'trolls', 'shire', 'here', 'catapulting', 'the', 'mind', 'marries', 'destroyed', 'havens', 'gates', 'swears', 'can', 'children', 'torrents', 'met', 'ten', 'used', 'discovers', 'mithril', 'save', 'feasting', 'with', 'against', 'weathertop', 'muster', 'astin', 'vision', 'shows', 'hope', 'next', 'book', 'sunset', 'weaving', ';', 'her', 'flashes', 'struggling', 'master', 'their', 'noon', 'manipulates', 'alive', 'deliver', 'have', 'stone', 'mad', 'referring', 'knowing', 'might', 'move', 'again.leaving', 'reforged', 'same', 'so', 'reaching', 'charge', 'i', 'grond', 'prepared', 'measures', 'war', 'defenders.away', 'control', 'while', 'aragorn', 'each', 'new', 'arrow', 'edoras', 'rides', "'hail", 'huge', 'charges', 'screen', 'ensuing', 'should', 'not', 'side', 'murmur', 'poisons', 'penetrates', 'prevent', 'group', 'only', 'an', 'has', 'engages', 'deduces', 'across', 'rhys-davies', 'meal', 'composed', 'concerns', 'racing', 'wreckage', 'pries', 'pulling', 'guide', 'extremely', 'midst', 'moving', 'doom', 'draw', 'voice', 'also', 'wenham', 'figure', 'however', 'two', 'makeshift', 'said', 'fell', 'contingent', 'named', 'turn', 'act', 'arrival', 'riders', 'puts', 'was', 'wood', 'encamped', 'eye', 'stinger.in', 'built', 'hugo', 'arrive', 'wards', 'proposes', 'rescue', 'elendil', 'cut', 'beasts', 'grief', 'retreating', 'captured', 'part', 'intervenes', 'mental', 'saying', 'dourif', 'sinks', 'white', 'himself', 'steward', 'legolas', 'kill', 'overhears', 'mountains', 'palantă\xadr', 'squabble', 'killing', 'andy', 'creature', 'failing', 'collapses', 'edge', 'karl', 'noise', 'surviving', 'streets', 'coma.at', 'gondorians', 'eldar', 'fades', 'convincing', 'accepts', 'counsel', 'following', 'denethor', 'men', 'pippin', 'but', 'look', 'ablaze', 'up', 'drive', 'grima', 'flotsam', 'entire', 'falls', 'lee', 'loses', 'serkis', 'brad', 'then', 'all', 'home', 'through', 'sway', 'pursued', 'struggle', 'provisions', 'mindolluin', 'fatally', 'lone', 'strangles', 'shatters', ' ...

# %%
from collections import Counter
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

# %%
## BAG OF WORDS ##

# Count number of occurences of each token
count = Counter(lower_tokens)

# Retain alphabetic words: alpha_only
alpha_only = [t for t in lower_tokens if t.isalpha()]

# Get a list of english stopwords
english_stops = set(stopwords.words('english'))

# Remove all stop words: no_stops
no_stops = [t for t in alpha_only if t not in english_stops]

# Instantiate the WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()

# Lemmatize (group together the inflected forms of a word 
# so they can be analysed as a single item) all tokens into a new list: lemmatized

lemmatized = [wordnet_lemmatizer.lemmatize(t) for t in no_stops]

# Create the bag-of-words: bow
bow = Counter(lemmatized)

# Print the 10 most common tokens
print(bow.most_common(10))
# Out:
# [('frodo', 27), ('sam', 25), ('aragorn', 23), ('gollum', 21), ('gandalf', 17), ('ring', 16), ('pippin', 15), ('faramir', 12), ('mina', 11), ('orcs', 11)]

# %%
import gensim

# %%
## GENSIM CORPUS ##
from gensim.corpora.dictionary import Dictionary

# Create a Dictionary from the <<list of token lists for each file>>: dictionary ??????????????????????
dictionary = Dictionary(files)

# Create a MmCorpus: corpus
corpus = [dictionary.doc2bow(file) for file in files]

# Print the first 10 word ids with their frequency counts from the first document
print(corpus[0][:10])

# %%
## TF - IDF ##

from gensim.models.tfidfmodel import TfidfModel


# Create a new TfidfModel using the corpus: tfidf
tfidf = TfidfModel(corpus)

# Calculate the tfidf weights of doc: tfidf_weights
tfidf_weights = tfidf[bow]


# Sort the weights from highest to lowest: sorted_tfidf_weights
sorted_tfidf_weights = sorted(tfidf_weights, key=lambda w: w[1], reverse=True)

# Print the top 5 weighted words
for term_id, weight in sorted_tfidf_weights[:5]:
    print(dictionary.get(term_id),weight)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-6d5d40b3fe27> in <module>()
#       5
#       6 # Create a new TfidfModel using the corpus: tfidf
# ----> 7 tfidf = TfidfModel(corpus)
#       8
#       9 # Calculate the tfidf weights of doc: tfidf_weights
#
# NameError: name 'corpus' is not defined

# %%
## Named Entity Recognition with spaCy ##

import spacy

# Convert list of alpha-numeric tokens into a string: string 
alphanum = [t for t in tokens if t.isalpha()]
string=' '.join(set(alphanum))

# Load spacy model for English: nlp
nlp = spacy.load('en_core_web_sm', tagger=False, parser=False, matcher=False)

# Process whole documents
doc = nlp(string)

# Create a list of NERs
ner=[]
for entity in doc.ents:
    ner.append(entity.text)
    print(entity.text, entity.label_)
# Out:
# Weaving Gollum PERSON
# Anduril PERSON
# Beasts NORP
# Boromir Gimli PERSON
# Rohan GPE
# Mindolluin GPE
# Rivendell PERSON
# Eagles ORG
# Realizing Bilbo ORG
# Christopher PERSON
# Arwen PERSON
# Merry PERSON
# Brad PERSON
# David PERSON
# Aragorn Boyd PERSON
# Ian PERSON
# Army ORG
# Shire PERSON
# Deep PERSON
# Galadriel ORG
# Bernard Orthanc PERSON
# Karl McKellen PERSON
# first ORDINAL
# Sam PERSON
# Bag PERSON
# Pippin ORG
# Monaghan PERSON
# Fields PERSON
# Grey PERSON
# trolls War catapulting EVENT
# Wood LOC
# Isildur GPE
# ten CARDINAL
# Frodo ORG
# Legolas PERSON
# Rohirrim NORP
# noon TIME
# Morgul GPE
# Wenham PERSON
# Brophy Eldarion ORG
# John NazgĂ PERSON
# Rosie PERSON
# Tyler PERSON
# Hugo EVENT
# Noble ORG
# McLeod Gate ORG
# Hill ORG
# Andy MĂ PERSON
# Bean PERSON
# Nazgul PERSON
# two CARDINAL
# Treebeard PERSON
# Havens PERSON
# Gondorian NORP
# Steward PERSON
# Battle PERSON
# Ungol PERSON
# West LOC
# Suffering GPE
# Gondorians NORP
# Grond GPE
# One CARDINAL
# half CARDINAL
# Straight Middle LOC
# Otto PERSON
# Liv Sarah PRODUCT
# Thomas PERSON
# Crack PERSON
# Hallows ORG
# City PRODUCT
# Grima PERSON
# six CARDINAL
# Dourif GPE
# Denethor PERSON
# Dominic ORG
# night TIME
# River Saruman NORP
# Elrond ORG
# Mordor GPE
# Robins PERSON
# White Snowmane PERSON
# Fangorn Urban PERSON
# Harad ORG
# Cotton NORP
# Orc PERSON
# Mortensen PERSON
# Stair NORP
# Serkis ORG
# Helm Precious PERSON
# Astin PERSON
# Corsairs GPE
# Anduin Eldar Shelob ORG
# Minas GPE
# Tower GPE
# morning TIME
# Weathertop PERSON
# Billy PERSON
# Uttermost ORG
# Flame ORG
# Sauron ORG
# Bloom ORG
# Gladden Earth LOC
# Miranda Elendil Dunharrow LAW
# Down PERSON
# Ring North PERSON
# Angmar ORG
# Black PERSON
# Valinor PERSON
# Lee PERSON
# Elijah NORP
# Faramir PERSON
# Edoras PERSON
# Ringwraiths PERSON
# Tree Tirith PERSON
# Orlando GPE
# Narsil PERSON
# Ithilien However PERSON
# Hornburg GPE

# %%
from spacy import displacy
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5">oath alcove finished sewing manage Surrounded furtive beacon
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Weaving Gollum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  pain life known crosses awake
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Anduril
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  suffering tortures precipice dropping begins shuts
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Beasts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  terror exhaustion opposes recall walks Dimholt remain father a jumps looting outskirts says ordering lest food continues Eye climbs closer
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Boromir Gimli
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  towards lightning carry bare holds she victory upper
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Rohan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  caves
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Mindolluin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  makil affection heir assuming city feet before break fortify
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Rivendell
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  leading to long thousand walls Lands skirmish lava consumed
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Eagles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  back may be
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Realizing Bilbo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  eating stabs lied burning slinking spent
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Christopher
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  saving treachery sight lights enemy hands marshaled route promise unconscious
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Arwen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  horse way family boats brief submitted
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Merry
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  amongst ensues he trying ring
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Brad
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  flashback sends recompense quickly encampment days once lair cunning
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     David
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  believes wounding curse in
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Aragorn Boyd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  empathises
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Ian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  allegiance
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Army
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  thrown
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Shire
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  amidst loyalty Before ref

# %%
# Remove all NER: no_ner
no_ner = [t.lower() for t in set(lemmatized) if t not in ner]

# Print unique no-NER tokens
print(set(no_ner))
# Out:
# {'rivendell', 'solace', 'finally', 'forest', 'shatters', 'pain', 'cirith', 'sauron', 'nick', 'faction', 'lied', 'knife', 'terror', 'city', 'merry', 'hooded', 'victory', 'promise', 'edge', 'long', 'show', 'likewise', 'center', 'lava', 'open', 'bag', 'headed', 'massacring', 'abandon', 'collapse', 'honorable', 'wall', 'recognises', 'decides', 'swears', 'ensuing', 'keeping', 'start', 'order', 'belief', 'succumbs', 'dangerous', 'sword', 'try', 'earth', 'rider', 'son', 'captain', 'wound', 'trapped', 'shire', 'legolas', 'enemy', 'affection', 'straight', 'prepares', 'fellowship', 'strangles', 'elrond', 'locate', 'suddenly', 'injury', 'mcleod', 'intervenes', 'rest', 'set', 'see', 'ship', 'force', 'monaghan', 'karl', 'ram', 'solitary', 'rock', 'master', 'mortensen', 'leading', 'squabble', 'true', 'mind', 'hugo', 'reforge', 'saying', 'assuming', 'curiosity', 'orcs', 'refuse', 'soldier', 'rosie', 'recovers', 'death', 'eye', 'birthday', 'last', 'surviving', 'stair', 'ordeal', 'surrounding', 'weaving', 'nazgă', 'retreat', 'skirmish', 'quest', 'rohirrim', 'play', 'spent', 'cross', 'viggo', 'fortify', 'explodes', 'among', 'come', 'sewing', 'trek', 'saruman', 'relieving', 'wreckage', 'muster', 'dunharrow', 'seizing', 'legion', 'uttermost', 'poison', 'head', 'prove', 'treachery', 'back', 'leave', 'road', 'failed', 'upon', 'john', 'dragged', 'met', 'kneel', 'mă', 'eats', 'manipulates', 'anduril', 'succumb', 'ward', 'insists', 'gladden', 'annihilate', 'stirring', 'beast', 'knowing', 'reuniting', 'questioning', 'look', 'faramir', 'break', 'flotsam', 'everybody', 'become', 'osgiliath', 'thereby', 'tower', 'biting', 'hornburg', 'go', 'get', 'offer', 'mordor', 'orthanc', 'short', 'power', 'empathises', 'next', 'arrow', 'composed', 'measure', 'outskirt', 'anduin', 'homage', 'dropping', 'remaining', 'turn', 'gandalf', 'scene', 'followed', 'flash', 'influence', 'control', 'route', 'deep', 'haven', 'bed', 'entire', 'shuts', 'fire', 'hidden', 'accursed', 'urban', 'instead', 'opposes', 'funeral', 'signal', 'sway', 'newly', 'continues', 'foretold', 'terribly', 'unaware', 'west', 'huge', 'gimli', 'urge', 'send', 'prisoner', 'precipice', 'growing', 'mount', 'fondling', 'dourif', 'great', 'taking', 'heir', 'cotton', 'shore', 'mckellen', 'dispatch', 'manage', 'lie', 'seems', 'lightning', 'still', 'hand', 'fulfilled', 'destruction', 'ill', 'westmarch', 'reveals', 'stone', 'near', 'shirt', 'steep', 'notice', 'boat', 'unconscious', 'little', 'use', 'reclaimed', 'wounding', 'disappearing', 'arwen', 'field', 'trebuchet', 'night', 'rejoices', 'kill', 'waterwheel', 'man', 'help', 'fall', 'along', 'find', 'golden', 'dimholt', 'gondorians', 'andy', 'new', 'joy', 'victorious', 'encampment', 'talking', 'elijah', 'glower', 'beneath', 'murmur', 'destroying', 'lest', 'stranded', 'lee', 'morgul', 'remain', 'siege', 'battle', 'loses', 'heralding', 'said', 'path', 'greeted', 'sends', 'fist', 'retreating', 'david', 'crawl', 'middle', 'way', 'darker', 'thrown', 'entranced', 'found', 'walk', 'finished', 'glinting', 'hallows', 'helpful', 'dead', 'boyd', 'surrounded', 'barely', 'state', 'anything', 'weathertop', 'dy', 'saving', 'struggling', 'alert', 'shockwave', 'carry', 'killing', 'paralysed', 'river', 'meet', 'corsair', 'door', 'refused', 'necessary', 'trust', 'following', 'forth', 'step', 'dwindles', 'moving', 'miranda', 'closer', 'incapacitates', 'convinces', 'reclaim', 'street', 'anymore', 'liv', 'treebeard', 'might', 'sun', 'investigate', 'gondor', 'edoras', 'noble', 'vision', 'mad', 'submitted', 'ungol', 'catapult', 'looting', 'understands', 'well', 'eruption', 'sarah', 'foot', 'day', 'hold', 'powerful', 'robin', 'call', 'outpouring', 'snowmane', 'may', 'hears', 'shame', 'mental', 'lone', 'attraction', 'sail', 'throat', 'oath', 'grey', 'bean', 'left', 'harad', 'landing', 'sunset', 'move', 'demand', 'ian', 'happy', 'l', 'wenham', 'sight', 'awake', 'witnessed', 'sings', 'prediction', 'galadriel', 'tree', 'reaching', 'return', 'destroyed', 'isengard', 'say', 'cut', 'exhaustion' ...
