# %%
import nltk
import pandas as pd
import glob
import re
from nltk.tokenize import word_tokenize

# %%
path =r'movies_txt_storylines' # use your path
allFiles = glob.glob(path + "/*.txt")
frame = pd.DataFrame()
list_ = []
for index, file_ in enumerate(allFiles):
    print(file_)
    df = pd.read_csv(file_,sep=';;;',header=None)
    df.columns = ['synopses']
    df['index'] = index
    file_ = file_.split("/")
    file_ = file_[1].split("_")
    genre = file_[1].split(".")
    genre2 = re.sub('\d+', '', genre[0])
    df['title'] = file_[0]
    df['genre'] = genre2
    
    list_.append(df)

frame = pd.concat(list_)
frame
# Out:
# movies_txt_storylines/(500) Days of Summer_romance19.txt
# movies_txt_storylines/300 _action24.txt
# movies_txt_storylines/300 _fantasy14.txt
# movies_txt_storylines/Avatar _action9.txt
# movies_txt_storylines/Avatar _fantasy5.txt
# movies_txt_storylines/Back to the Future_comedy1.txt
# movies_txt_storylines/Batman Begins_action6.txt
# movies_txt_storylines/Casablanca _romance15.txt
# movies_txt_storylines/Cast Away_romance14.txt
# movies_txt_storylines/Crazy, Stupid, Love._romance20.txt
# movies_txt_storylines/Deadpool _action20.txt
# movies_txt_storylines/Deadpool _comedy6.txt
# movies_txt_storylines/Deadpool _romance5.txt
# movies_txt_storylines/Die Hard_action23.txt
# movies_txt_storylines/Edward Scissorhands_romance23.txt
# movies_txt_storylines/Eternal Sunshine of the Spotless Mind_romance3.txt
# movies_txt_storylines/Finding Nemo_comedy2.txt
# movies_txt_storylines/Forrest Gump _romance0.txt
# movies_txt_storylines/Friends_comedy16.txt
# movies_txt_storylines/Friends_romance9.txt
# movies_txt_storylines/Game of Thrones_action3.txt
# movies_txt_storylines/Game of Thrones_fantasy2.txt
# movies_txt_storylines/Game of Thrones_romance1.txt
# movies_txt_storylines/Gladiator _action5.txt
# movies_txt_storylines/Groundhog Day_comedy23.txt
# movies_txt_storylines/Groundhog Day_romance12.txt
# movies_txt_storylines/Guardians of the Galaxy_action15.txt
# movies_txt_storylines/Harry Potter and the Deathly Hallows Part 2_fantasy15.txt
# movies_txt_storylines/Her_romance18.txt
# movies_txt_storylines/How I Met Your Mother_comedy22.txt
# movies_txt_storylines/How I Met Your Mother_romance11.txt
# movies_txt_storylines/How to Train Your Dragon_comedy18.txt
# movies_txt_storylines/How to Train Your Dragon_fantasy23.txt
# movies_txt_storylines/Inception_action1.txt
# movies_txt_storylines/Indiana Jones and the Last Crusade_fantasy21.txt
# movies_txt_storylines/Intouchables_comedy13.txt
# movies_txt_storylines/Iron Man _action17.txt
# movies_txt_storylines/Kill Bill Vol. 1_action14.txt
# movies_txt_storylines/Kingsman The Secret Service_comedy24.txt
# movies_txt_storylines/Le fabuleux destin d'Amélie Poulain_comedy12.txt
# movies_txt_storylines/Le fabuleux destin d'Amélie Poulain_romance6.txt
# movies_txt_storylines/Mad Max Fury Road_action21.txt
# movies_txt_storylines/Man of Steel_fantasy18.txt
# movies_txt_storylines/Monsters, Inc._comedy8.txt
# movies_txt_storylines/Monsters, Inc._fantasy13.txt
# movies_txt_storylines/Mr. & Mrs. Smith _romance24.txt
# movies_txt_storylines/Pirates of the Caribbean Dead Man's Chest_fantasy22.txt
# movies_txt_storylines/Pirates of the Caribbean The Curse of the Black Pearl_action11.txt
# /Applications/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   import sys
#                                              synopses  index  \
# 0   (500) Days of Summer is presented in a non-chr...      0
# 0   Spartan customs are harsh. The Spartans inspec...      1
# 0   Spartan customs are harsh. The Spartans inspec...      2
# 0   Opening scene: a camera sweeps high across the...      3
# 0   Opening scene: a camera sweeps high across the...      4
# 0   The title logo appears on a black background. ...      5
# 0   The film's story is divided into three time-li...      6
# 0   In the early years of World War II, December 1...      7
# 0   Chuck Nolan (Tom Hanks) is a systems engineer ...      8
# 0   Cal Weaver (Steve Carell) gets the surprise of...      9
# 0   The opening scene shows Wade Wilson, the super...     10
# 0   The opening scene shows Wade Wilson, the super...     11
# 0   The opening scene shows Wade Wilson, the super...     12
# 0   John McClane, a detective with the New York Ci...     13
# 0   One evening, an elderly woman tells her grandd...     14
# 0   Joel Barish (Jim Carrey) is an emotionally wit...     15
# 0   Two clownfish, Marlin (Albert Brooks) and his ...     16
# 0   The film begins with a feather falling to the ...     17
# 0   It looks like we don't have a Synopsis for thi...     18
# 0   It looks like we don't have a Synopsis for thi...     19
# 0   Three men set out on horseback on a snowy land...     20
# 1   We see their bodies are laid out in a kind of ...     20
# 2   Bran lets fly his arrow and misses wildly.Sudd...     20
# 3   A funeral takes place in the grand cathedral.S...     20
# 4   Cat tells her husband the news of Jon Arryns d...     20
# 5   King Robert of Baratheon and Queen Cersei are ...     20
# 6   They greet each other warmly. Arya is eager to...     20
# 7   Down there, Robert says Arryn got sick suddenl...     20
# 8   Across the Narrow SeaPrincess Daenerys Targary...     20
# 9   Arya gets removed from the party for flicking ...     20
# ..                                                ...    ...
# 12  * Stu ripping his tooth out of his mouth with ...     79
# 13        * The guys together before the night began.     79
# 0   Prologue: During the preparations for the birt...     80
# 0   In a flashback set in the town of Bree on the ...     81
# 0   The prologue, spoken by Galadriel, shows the D...     82
# 0   In the opening scene, a flashback, two hobbits...     83
# 0   The film begins with a flashback set to the fi...     84
# 1   Back in Osgiliath, the Hobbits are confronted ...     84
# 0   The screen is filled with green, cascading cod...     85
# 0   In a modern-day nursing home, an elderly man n...     86
# 0   The movie opens with Charlie (Logan Lerman) wr...     87
# 0   Over an apocalyptic battlefield in the year 20...     88
# 0   Truman Burbank (Jim Carrey) is an insurance sa...     89
# 0   The movie opens with a TV advertisement for St...     90
# 0   Three scientists, Jane Foster (Natalie Portman...     91
# 0   In 1996, treasure hunter Brock Lovett and his ...     92
# 1   In 1912 Southampton, 17-year-old first-class p...     92
# 2   Aware of Cal and Ruth's disapproval, Rose rebu...     92
# 3   Cal discovers Jack's sketch of Rose and a mock...     92
# 4   With the ship sinking, Rose is desperate to fr...     92
# 5   After braving several obstacles, Jack and Rose...     92
# 6   With Rose hiding from Cal en route, the RMS Ca...     92
# 7   Lovett abandons his search after hearing Rose'...     92
# 0   Andy Davis (voice: John Morris) is 17 years ol...     93
# 0   Andy Davis (voice: John Morris) is 17 years ol...     94
# 0   A boy called Andy Davis (voice: John Morris) u...     95
# 0   A boy called Andy Davis (voice: John Morris) u...     96
# 0   The story takes place in the fertile, eastern ...     97
# 0   Young Carl Fredricksen (Jeremy Leary), a quiet...     98
# 0   "Remember, remember the fifth of November, the...     99
#
#                                                title    genre
# 0                               (500) Days of Summer  romance
# 0                                               300    action
# 0                                               300   fantasy
# 0                                            Avatar    action
# 0                                            Avatar   fantasy
# 0                                 Back to the Future   comedy
# 0                                      Batman Begins   action
# 0                                        Casablanca   romance
# 0                                          Cast Away  romance
# 0                               Crazy, Stupid, Love.  romance
# 0                                          Deadpool    action
# 0                                          Deadpool    comedy
# 0                                          Deadpool   romance
# 0                                           Die Hard   action
# 0                                Edward Scissorhands  romance
# 0              Eternal Sunshine of the Spotless Mind  romance
# 0                                       Finding Nemo   comedy
# 0                                      Forrest Gump   romance
# 0                                            Friends   comedy
# 0                                            Friends  romance
# 0                                    Game of Thrones   action
# 1                                    Game of Thrones   action
# 2                                    Game of Thrones   action
# 3                                    Game of Thrones   action
# 4                                    Game of Thrones   action
# 5                                    Game of Thrones   action
# 6                                    Game of Thrones   action
# 7                                    Game of Thrones   action
# 8                                    Game of Thrones   action
# 9                                    Game of Thrones   action
# ..                                               ...      ...
# 12                                      The Hangover   comedy
# 13                                      The Hangover   comedy
# 0                   The Hobbit An Unexpected Journey  fantasy
# 0                 The Hobbit The Desolation of Smaug  fantasy
# 0   The Lord of the Rings The Fellowship of the Ring  fantasy
# 0       The Lord of the Rings The Return of the King  fantasy
# 0               The Lord of the Rings The Two Towers  fantasy
# 1               The Lord of the Rings The Two Towers  fantasy
# 0                                         The Matrix   action
# 0                                       The Notebook  romance
# 0                    The Perks of Being a Wallflower  romance
# 0                                     The Terminator   action
# 0                                    The Truman Show   comedy
# 0                            The Wolf of Wall Street   comedy
# 0                                              Thor   fantasy
# 0                                           Titanic   romance
# 1                                           Titanic   romance
# 2                                           Titanic   romance
# 3                                           Titanic   romance
# 4                                           Titanic   romance
# 5                                           Titanic   romance
# 6                                           Titanic   romance
# 7                                           Titanic   romance
# 0                                       Toy Story 3    comedy
# 0                                       Toy Story 3   fantasy
# 0                                         Toy Story    comedy
# 0                                         Toy Story   fantasy
# 0                                               Troy  romance
# 0                                                 Up   comedy
# 0                                     V for Vendetta   action
#
# [176 rows x 4 columns]

# %%
## TOKENIZATION ##

# Open file:
with open('fantasy0.txt', 'r') as file:
    for line in file:    
        # Split file into words: words
        tokens = word_tokenize(line)
        # Convert the tokens into lowercase: lower_tokens
        lower_tokens = [t.lower() for t in tokens]

# Print the unique tokens result
print(lower_tokens)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-34-e7273a14d4ea> in <module>()
#       2
#       3 # Open file:
# ----> 4 with open('fantasy0.txt', 'r') as file:
#       5     for line in file:
#       6         # Split file into words: words
#
# FileNotFoundError: [Errno 2] No such file or directory: 'fantasy0.txt'

# %%
from collections import Counter
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

# %%
## BAG OF WORDS ##

# Count number of occurences of each token
count = Counter(lower_tokens)

# Retain alphabetic words: alpha_only
alpha_only = [t for t in lower_tokens if t.isalpha()]

# Get a list of english stopwords
english_stops = set(stopwords.words('english'))

# Remove all stop words: no_stops
no_stops = [t for t in alpha_only if t not in english_stops]

# Instantiate the WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()

# Lemmatize (group together the inflected forms of a word 
# so they can be analysed as a single item) all tokens into a new list: lemmatized

lemmatized = [wordnet_lemmatizer.lemmatize(t) for t in no_stops]

# Create the bag-of-words: bow
bow = Counter(lemmatized)

# Print the 10 most common tokens
print(bow.most_common(10))
# Out:
# [('frodo', 27), ('sam', 25), ('aragorn', 23), ('gollum', 21), ('gandalf', 17), ('ring', 16), ('pippin', 15), ('faramir', 12), ('mina', 11), ('orcs', 11)]

# %%
import spacy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c080f6458562> in <module>()
# ----> 1 import spacy
#
# ModuleNotFoundError: No module named 'spacy'
